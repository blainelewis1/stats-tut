# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.arange(0,1,0.1)

linear_menu = 5
shortcut = 1

slow_menu = 6
fast_menu = 0.1

T = linear_menu * (1 - x) + shortcut * x
T2 = slow_menu * (1 - x) + fast_menu * x


plt.plot(x, T)
plt.plot(x, T2)
